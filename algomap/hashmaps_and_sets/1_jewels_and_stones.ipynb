# %% [markdown]
# # Leetcode 771
#
# https://leetcode.com/problems/jewels-and-stones/description/
#
# **You're given strings jewels representing the types of stones that are jewels, and stones representing the stones you have. Each character in stones is a type of stone you have. You want to know how many of the stones you have are also jewels.**
#
# **Letters are case sensitive, so "a" is considered a different type of stone from "A".**
#
#
#
# ### Example 1:
#
# **Input**: jewels = "aA", stones = "aAAbbbb"
#
# **Output**: 3
#
# ### Example 2:
#
# **Input**: jewels = "z", stones = "ZZ"
#
# **Output**: 0

# %%
class Solution:
    def numJewelsInStones(self, jewels: str, stones: str) -> int:
        jewels_set = set(jewels) # Time: O(n), Space: O(n)
        count = 0 # Time: O(1), Space(1)

        for stone in stones: # Time: O(n), Space: O(1)
            if stone in jewels_set: # Time: O(1), Space O(n)
                count += 1 # Time: O(1), Space: O(1)
        
        return count

# Time: O(n), Space: O(n)

s = Solution()
print(s.numJewelsInStones('aA', 'aAAbbb'))
print(s.numJewelsInStones('z', 'ZZZ'))
# Out:
# 3
# 0
